# %% [markdown]
# <a href="https://colab.research.google.com/github/Odigie43/Image-manipulation/blob/main/Colour_Space.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Task : to convert BRG to RBG
#
# ✅ Mount your Google Drive
#
# ✅ `import` the OpenCV library
#
# ✅  Read a sample image (it can be any of your images stored in Google Drive. It is Better to be __colour__ image)
#
# ✅ Display the image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2

# %%
image=cv2.imread('/content/drive/MyDrive/dogs/images (1).jpg')
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FABCE8E33A0>

# %% [markdown]
# ## Task 2: Display images by using MatplotLib
#
# We will display some extra information and use subplots by using functions from `Matplotlib` since the basic `imshow()` cannot show all those advanced layouts.
#
# ✅ `import matplotlib.pyplot as plt`

# %%
#Your code goes here
import matplotlib.pyplot as plt

# %%
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGRA2RGB))

# %% [markdown]
# ## Task 3: Change BGR to RGB (reverse the default OpenCV colour space/model)
#
# There are many way to do it.
#
# ✅ Use `cvtColor()` function. You can check the example from [here](https://www.geeksforgeeks.org/convert-bgr-and-rgb-with-python-opencv/#:~:text=OpenCV%20uses%20BGR%20image%20format.%20So%2C%20when%20we,cv2.COLOR_RGB2BGR%20%E2%80%93%20RGB%20image%20is%20converted%20to%20BGR.)
#
# ✅ __[Bonus]__ Can you create your own function to convert the BGR to RGB?
#
# ✅ using the 'imshow()' from __matplotlib__ again. Is the colour problem solved?

# %%
#Your code goes he
# converting BGR to RGB
def bgr2rgb(image):
  output_image=image[:,:,::-1]
  return output_image

cut=bgr2rgb(image)
plt.imshow(cut)

# %%
#Demo
R=image_rgb[:,:,0]
G=image_rgb[:,:,1]
B=image_rgb[:,:,2]
fig, axes =plt.subplots(nrows=1,ncols=3,figsize=(15,5))

axes[0].imshow(R)
axes[1].imshow(G)
axes[2].imshow(B)

# %% [markdown]
# ## Task 4: BGR/RGB to HSV
#
# ✅ Use `cvtColor()` function (__again__).
#
# ✅ Display three channels (H, S, and V) as separate images
#
# ✅ Discuss the output (why the images look like this and what is the advantage of using HSV instead of RGB)
#
# ✅ __[Bonus]__ Create RGB to HSV function by yourself from scratch (only use NumPy for matrix operations)

# %%
image_HSV =cv2.cvtColor(image_rgb,cv2.COLOR_RGB2HSV)
H=image_HSV[:,:,0]
s=image_HSV[:,:,1]
v=image_HSV[:,:,2]

fig, axes =plt.subplots(nrows=1,ncols=3,figsize=(15,5))

plt.colorbar(axes[0].imshow(H,cmap='hsv'),ax=axes[0],orientation='horizontal')
plt.colorbar(axes[1].imshow(H,cmap='Greys_r'),ax=axes[1],orientation='horizontal')
plt.colorbar(axes[2].imshow(H,cmap='Greys_r'),ax=axes[2],orientation='horizontal')
